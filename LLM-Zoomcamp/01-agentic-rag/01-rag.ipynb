# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
# Load environment variables and imports
from dotenv import load_dotenv
load_dotenv()
import os

# %%
# Create the OpenAI client from the environment variable
from openai import OpenAI
openai_client = OpenAI(api_key=os.getenv("OPEN_API_KEY"))
# Out:
# None

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag("I just discovered the course, can I still join?")
# Out:
# 'Yes, you can still join the course whenever you want. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted during the live cohort.'
